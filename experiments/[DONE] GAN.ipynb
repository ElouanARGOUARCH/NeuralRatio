# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2
from targets import Target
from models import GenerativeAdversarialNetwork
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
example =  "Moons"
num_samples = 10000
target =Target(example, num_samples)
target.target_visual()
p, target_log_density, target_samples = target.get_target()

# %%
epochs = 200
networks_dims = [256,256,256]
GAN = GenerativeAdversarialNetwork(target_samples,p,networks_dims)
GAN.train(epochs)
# Out:
#  19%|██████████████████████▍                                                                                               | 38/200 [01:06<04:44,  1.76s/it, loss = 0.0010059300111606717]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2524/4055581935.py in <module>
#       2 networks_dims = [256,256,256]
#       3 GAN = GenerativeAdversarialNetwork(target_samples,p,networks_dims)
# ----> 4 GAN.train(epochs)
#
# ~\PycharmProjects\Neural-Density-Ratio\models\generative_adversarial_network.py in train(self, epochs, batch_size)
#      64             for i in range(int(self.num_samples / batch_size) + 1 * (int(self.num_samples / batch_size) != self.num_samples / batch_size)):
#      65                 self.optimizer_generator.zero_grad()
# ---> 66                 batch_loss_generator = - self.loss_generator(self.target_samples[perm][i * batch_size:min((i + 1) * batch_size, self.num_samples)])
#      67                 batch_loss_generator.backward()
#      68                 self.optimizer_generator.step()
#
# ~\PycharmProjects\Neural-Density-Ratio\models\generative_adversarial_network.py in loss_generator(self, X)
#      47         log_sigmoid = torch.nn.LogSigmoid()
#      48         fake = self.sample_generator(X.shape[0])
# ---> 49         return -torch.mean(log_sigmoid(-self.logit_r_network(fake)))
#      50
#      51     def train(self, epochs, batch_size = None):
#
# c:\users\ea264728\pycharmprojects\neural-density-ratio\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\ea264728\pycharmprojects\neural-density-ratio\venv\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# c:\users\ea264728\pycharmprojects\neural-density-ratio\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\ea264728\pycharmprojects\neural-density-ratio\venv\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# c:\users\ea264728\pycharmprojects\neural-density-ratio\venv\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %%
GAN.model_visual()

# %%
samples = GAN.sample_generator(5000)

# %%
import matplotlib.pyplot as plt 
plt.scatter(samples[:,0].cpu().detach().numpy(), samples[:,1].cpu().detach().numpy())
