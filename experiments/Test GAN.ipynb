# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2
from targets.density_estimation_target import *
from utils.visual import *
from models import GAN
import torch
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
###2D Example###
num_samples = 50000
target =Moons()
target.target_visual()
target_samples = target.sample(num_samples)

# %%
gan = GAN(target_samples,2, hidden_dims = [64,64,64])
gan.train(100,5000)
# Out:
# ...
#  10%|█████████████                                                                                                                      | 10/100 [04:29<40:28, 26.99s/it, loss = 0.001309]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2956/750672477.py in <module>
#       1 gan = GAN(target_samples,2, hidden_dims = [64,64,64])
# ----> 2 gan.train(100,5000)
#
# ~\PycharmProjects\Neural-Density-Ratio\models\gan.py in train(self, epochs, batch_size)
#      71                 self.discriminator_optimizer.zero_grad()
#      72                 discriminator_batch_loss = self.loss_discriminator(self.target_samples)
# ---> 73                 discriminator_batch_loss.backward()
#      74                 self.discriminator_optimizer.step()
#      75             fig = plt.figure()
#
# ...

# %%
with torch.no_grad():
    samples = gan.sample(1000)
    plt.scatter(samples[:,0].numpy(), samples[:,1].numpy())
# Out:
# estimating rejection sampling constant
